# %% [markdown]
# # VGGFace (VGG16) Training

# %% [markdown]
# ## Import the necessary libraries

# %%
import matplotlib.pyplot as plt
import os
import sys
import tensorflow as tf
import warnings
from keras_vggface_TF.vggfaceTF import VGGFace
from keras_vggface_TF import utils

# %matplotlib inline

warnings.filterwarnings('ignore')
# Out:
# 2021-11-28 03:16:17.058552: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-11-28 03:16:17.058597: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
print('Python Version ' + sys.version)
print('TensorFlow Version ' + tf.__version__)

if int(sys.version[0]) < 3 or int(sys.version[2]) < 7:
    assert("Python version 3.7 or newer is required")
if int(tf.__version__[0]) < 2 or int(tf.__version__[2]) < 3:
    assert("Tensorflow version 2.3 or newer is required")
# Out:
# Python Version 3.9.0 (default, Nov 15 2020, 14:28:56)
# [GCC 7.3.0]
# TensorFlow Version 2.6.2

# %% [markdown]
# ## Set some common parameters

# %%
IMAGE_SIZE = 224
BATCH_SIZE = 16
EPOCHS = 300

CUR_PATH = os.path.abspath('')
TRAIN_PATH = CUR_PATH + '/../../../dataset/data/classified'
VALID_PATH = CUR_PATH + '/../../../dataset/data/validation'
TEST_PATH = CUR_PATH + '/../../../dataset/data/test'
SAVE_PATH = CUR_PATH + '/../../models'

os.makedirs(SAVE_PATH, exist_ok=True)

classes = {0 : "Baby",
           1 : "Not Baby"}

# %% [markdown]
# ## Define a Data Augmentation Proceedure / Function

# %%
def data_augment(image):
    p_spatial = tf.random.uniform([], 0, 1.0, dtype = tf.float32)
    p_rotate = tf.random.uniform([], 0, 1.0, dtype = tf.float32)
    p_pixel_1 = tf.random.uniform([], 0, 1.0, dtype = tf.float32)
    p_pixel_2 = tf.random.uniform([], 0, 1.0, dtype = tf.float32)
    p_pixel_3 = tf.random.uniform([], 0, 1.0, dtype = tf.float32)
    
    # Flips
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    
    if p_spatial > .75:
        image = tf.image.transpose(image)
        
    # Rotates
    if p_rotate > .75:
        image = tf.image.rot90(image, k = 3) # rotate 270º
    elif p_rotate > .5:
        image = tf.image.rot90(image, k = 2) # rotate 180º
    elif p_rotate > .25:
        image = tf.image.rot90(image, k = 1) # rotate 90º
        
    # Pixel-level transforms
    if p_pixel_1 >= .4:
        image = tf.image.random_saturation(image, lower = .7, upper = 1.3)
    if p_pixel_2 >= .4:
        image = tf.image.random_contrast(image, lower = .8, upper = 1.2)
    if p_pixel_3 >= .4:
        image = tf.image.random_brightness(image, max_delta = .1)
        
    return image

# %% [markdown]
# ## Define Data Generators

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255,
                                                          samplewise_center = True,
                                                          samplewise_std_normalization = True,
                                                          preprocessing_function = data_augment)

val_test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255,
                                                          samplewise_center = True,
                                                          samplewise_std_normalization = True)

val_test_datagen.apply_transform

train_ds = datagen.flow_from_directory(
        TRAIN_PATH,
        target_size=(IMAGE_SIZE, IMAGE_SIZE),
        batch_size=BATCH_SIZE,
        seed = 1,
        color_mode = 'rgb',
        shuffle = True,
        class_mode='binary')

val_ds = val_test_datagen.flow_from_directory(
        VALID_PATH,
        target_size=(IMAGE_SIZE, IMAGE_SIZE),
        batch_size=BATCH_SIZE,
        color_mode = 'rgb',
        shuffle = True,
        class_mode='binary')

test_ds = val_test_datagen.flow_from_directory(
        TEST_PATH,
        target_size=(IMAGE_SIZE, IMAGE_SIZE),
        batch_size=BATCH_SIZE,
        color_mode = 'rgb',
        class_mode='binary')
# Out:
# Found 135 images belonging to 2 classes.
# Found 31 images belonging to 2 classes.
# Found 18 images belonging to 2 classes.

# %%
x = train_ds.next()
image = x[0][0]
print(image.shape)
plt.imshow(image)
# Out:
# 2021-11-28 03:16:19.319564: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-11-28 03:16:19.319610: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-11-28 03:16:19.319641: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (snf-22339): /proc/driver/nvidia/version does not exist
# 2021-11-28 03:16:19.320121: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)

# %%
cat_img = plt.imread(TRAIN_PATH + '/baby/1.jpeg')

# %%
plt.imshow(cat_img)

# %% [markdown]
# ## Load the default VGGFace (VGG16) model

# %%
vgg_model = VGGFace(model='vgg16', include_top=False, input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3), pooling='avg')

# %% [markdown]
# ## Create a custom model

# %%
x = tf.keras.layers.Flatten(name='flatten')(vgg_model.output)
x = tf.keras.layers.Dense(32, activation='relu',)(x)
x = tf.keras.layers.Dense(16, activation='relu',)(x)
out = tf.keras.layers.Dense(1, activation='sigmoid', name='classifier')(x)
model = tf.keras.Model(vgg_model.input, out)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv1_1 (Conv2D)             (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv1_2 (Conv2D)             (None, 224, 224, 64)      36928
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2_1 (Conv2D)             (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2_2 (Conv2D)             (None, 112, 112, 128)     147584
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 56, 56, 128)       0
# _________________________________________________________________
# conv3_1 (Conv2D)             (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv3_2 (Conv2D)             (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv3_3 (Conv2D)             (None, 56, 56, 256)       590080
# _________________________________________________________________
# pool3 (MaxPooling2D)         (None, 28, 28, 256)       0
# _________________________________________________________________
# conv4_1 (Conv2D)             (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv4_2 (Conv2D)             (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv4_3 (Conv2D)             (None, 28, 28, 512)       2359808
# _________________________________________________________________
# pool4 (MaxPooling2D)         (None, 14, 14, 512)       0
# _________________________________________________________________
# conv5_1 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv5_2 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv5_3 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# pool5 (MaxPooling2D)         (None, 7, 7, 512)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                16416
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# classifier (Dense)           (None, 1)                 17
# =================================================================
# Total params: 14,731,649
# Trainable params: 14,731,649
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Define Callbacks

# %%
learning_rate = 1e-4

optimizer = tf.optimizers.Adam(learning_rate = learning_rate)

model.compile(optimizer = optimizer, 
              loss = tf.keras.losses.binary_crossentropy, 
              metrics = ['accuracy'])

STEP_SIZE_TRAIN = train_ds.n // train_ds.batch_size
# STEP_SIZE_VALID = val_ds.n // val_ds.batch_size

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_loss',
                                                 # verbose = 1,
                                                 factor = 0.2,
                                                 patience = 10,
                                                 min_delta = 1e-4,
                                                 min_lr = 1e-6,
                                                 mode = 'min')

earlystopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss',
                                                 # verbose = 1,
                                                 min_delta = 1e-4,
                                                 patience = 30,
                                                 mode = 'min',
                                                 restore_best_weights = True)

checkpointer = tf.keras.callbacks.ModelCheckpoint(monitor = 'val_loss',
                                                  # verbose = 1,
                                                  save_best_only = True,
                                                  save_weights_only = True,
                                                  mode = 'min',
                                                  filepath = './model_vggface_vgg.hdf5',
                                                  )

callbacks = [checkpointer, earlystopping, reduce_lr] #reduce_lr earlystopping

# %% [markdown]
# ## Training the Model

# %%
model.fit(x = train_ds,
          steps_per_epoch = STEP_SIZE_TRAIN,
          validation_data = val_ds,
          epochs = EPOCHS,
          callbacks = callbacks)

model.save(SAVE_PATH + '/model_vggface_vgg.h5')

os.remove('./model_vggface_vgg.hdf5')
# Out:
# 2021-11-28 03:16:21.240545: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/300
# 8/8 [==============================] - 58s 8s/step - loss: 0.6801 - accuracy: 0.4790 - val_loss: 0.6870 - val_accuracy: 0.5484
# Epoch 2/300
# 8/8 [==============================] - 57s 7s/step - loss: 0.6788 - accuracy: 0.6134 - val_loss: 0.6999 - val_accuracy: 0.5161
# Epoch 3/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.6624 - accuracy: 0.5966 - val_loss: 0.6342 - val_accuracy: 0.6452
# Epoch 4/300
# 8/8 [==============================] - 56s 7s/step - loss: 0.6393 - accuracy: 0.6555 - val_loss: 0.6192 - val_accuracy: 0.5484
# Epoch 5/300
# 8/8 [==============================] - 56s 7s/step - loss: 0.6736 - accuracy: 0.6387 - val_loss: 0.7810 - val_accuracy: 0.4839
# Epoch 6/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.6612 - accuracy: 0.6639 - val_loss: 0.6773 - val_accuracy: 0.6774
# Epoch 7/300
# 8/8 [==============================] - 57s 7s/step - loss: 0.6457 - accuracy: 0.7563 - val_loss: 0.6262 - val_accuracy: 0.6129
# Epoch 8/300
# 8/8 [==============================] - 56s 7s/step - loss: 0.5522 - accuracy: 0.7815 - val_loss: 0.5840 - val_accuracy: 0.6774
# Epoch 9/300
# 8/8 [==============================] - 56s 7s/step - loss: 0.4571 - accuracy: 0.7815 - val_loss: 0.5434 - val_accuracy: 0.7419
# Epoch 10/300
# 8/8 [==============================] - 57s 7s/step - loss: 0.4915 - accuracy: 0.7899 - val_loss: 0.6058 - val_accuracy: 0.6774
# Epoch 11/300
# 8/8 [==============================] - 56s 7s/step - loss: 0.6004 - accuracy: 0.7227 - val_loss: 0.6980 - val_accuracy: 0.5806
# Epoch 12/300
# 8/8 [==============================] - 56s 7s/step - loss: 0.4711 - accuracy: 0.8319 - val_loss: 0.5580 - val_accuracy: 0.7097
# Epoch 13/300
# 8/8 [==============================] - 62s 8s/step - loss: 0.4141 - accuracy: 0.8125 - val_loss: 0.7941 - val_accuracy: 0.7097
# Epoch 14/300
# 8/8 [==============================] - 56s 7s/step - loss: 0.3680 - accuracy: 0.8655 - val_loss: 0.9661 - val_accuracy: 0.5806
# Epoch 15/300
# 8/8 [==============================] - 56s 7s/step - loss: 0.3867 - accuracy: 0.8403 - val_loss: 0.4593 - val_accuracy: 0.7742
# Epoch 16/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.2477 - accuracy: 0.9160 - val_loss: 1.2034 - val_accuracy: 0.6129
# Epoch 17/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.4067 - accuracy: 0.8992 - val_loss: 0.4202 - val_accuracy: 0.8065
# Epoch 18/300
# 8/8 [==============================] - 54s 7s/step - loss: 0.3560 - accuracy: 0.8571 - val_loss: 0.5864 - val_accuracy: 0.7097
# Epoch 19/300
# 8/8 [==============================] - 59s 7s/step - loss: 0.3067 - accuracy: 0.8750 - val_loss: 0.4228 - val_accuracy: 0.8065
# Epoch 20/300
# 8/8 [==============================] - 53s 7s/step - loss: 0.2410 - accuracy: 0.9076 - val_loss: 0.4823 - val_accuracy: 0.7419
# Epoch 21/300
# 8/8 [==============================] - 58s 7s/step - loss: 0.3732 - accuracy: 0.8594 - val_loss: 0.4190 - val_accuracy: 0.7742
# Epoch 22/300
# 8/8 [==============================] - 53s 7s/step - loss: 0.2718 - accuracy: 0.8992 - val_loss: 0.5814 - val_accuracy: 0.7097
# Epoch 23/300
# 8/8 [==============================] - 54s 7s/step - loss: 0.2553 - accuracy: 0.8571 - val_loss: 0.5941 - val_accuracy: 0.7419
# Epoch 24/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.1959 - accuracy: 0.9328 - val_loss: 0.4982 - val_accuracy: 0.7097
# Epoch 25/300
# 8/8 [==============================] - 57s 7s/step - loss: 0.1975 - accuracy: 0.9141 - val_loss: 0.6386 - val_accuracy: 0.7419
# Epoch 26/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.2276 - accuracy: 0.9412 - val_loss: 0.7720 - val_accuracy: 0.6774
# Epoch 27/300
# 8/8 [==============================] - 56s 7s/step - loss: 0.2271 - accuracy: 0.9160 - val_loss: 0.7898 - val_accuracy: 0.7097
# Epoch 28/300
# 8/8 [==============================] - 56s 7s/step - loss: 0.2710 - accuracy: 0.8739 - val_loss: 0.4295 - val_accuracy: 0.8065
# Epoch 29/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.1921 - accuracy: 0.9328 - val_loss: 1.0648 - val_accuracy: 0.6452
# Epoch 30/300
# 8/8 [==============================] - 56s 7s/step - loss: 0.2417 - accuracy: 0.8908 - val_loss: 0.8367 - val_accuracy: 0.7097
# Epoch 31/300
# 8/8 [==============================] - 57s 7s/step - loss: 0.2539 - accuracy: 0.9076 - val_loss: 0.3950 - val_accuracy: 0.8065
# Epoch 32/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.2122 - accuracy: 0.9328 - val_loss: 1.0381 - val_accuracy: 0.6774
# Epoch 33/300
# 8/8 [==============================] - 57s 7s/step - loss: 0.1261 - accuracy: 0.9580 - val_loss: 0.7021 - val_accuracy: 0.7742
# Epoch 34/300
# 8/8 [==============================] - 57s 7s/step - loss: 0.2953 - accuracy: 0.8655 - val_loss: 0.5965 - val_accuracy: 0.7419
# Epoch 35/300
# 8/8 [==============================] - 57s 7s/step - loss: 0.2083 - accuracy: 0.8992 - val_loss: 0.4005 - val_accuracy: 0.8065
# Epoch 36/300
# 8/8 [==============================] - 56s 7s/step - loss: 0.1748 - accuracy: 0.9412 - val_loss: 0.8584 - val_accuracy: 0.6452
# Epoch 37/300
# 8/8 [==============================] - 56s 7s/step - loss: 0.1788 - accuracy: 0.9328 - val_loss: 1.2008 - val_accuracy: 0.6774
# Epoch 38/300
# 8/8 [==============================] - 57s 7s/step - loss: 0.1545 - accuracy: 0.9580 - val_loss: 0.3919 - val_accuracy: 0.7742
# Epoch 39/300
# 8/8 [==============================] - 57s 7s/step - loss: 0.1371 - accuracy: 0.9664 - val_loss: 0.7547 - val_accuracy: 0.7419
# Epoch 40/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.0930 - accuracy: 0.9580 - val_loss: 0.7795 - val_accuracy: 0.7742
# Epoch 41/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.0616 - accuracy: 0.9832 - val_loss: 0.8142 - val_accuracy: 0.7742
# Epoch 42/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.1414 - accuracy: 0.9412 - val_loss: 0.8589 - val_accuracy: 0.7419
# Epoch 43/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.1269 - accuracy: 0.9496 - val_loss: 0.6894 - val_accuracy: 0.7419
# Epoch 44/300
# 8/8 [==============================] - 54s 7s/step - loss: 0.1300 - accuracy: 0.9496 - val_loss: 0.4973 - val_accuracy: 0.7742
# Epoch 45/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.0826 - accuracy: 0.9748 - val_loss: 1.0722 - val_accuracy: 0.7097
# Epoch 46/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.2083 - accuracy: 0.9160 - val_loss: 0.5236 - val_accuracy: 0.7742
# Epoch 47/300
# 8/8 [==============================] - 54s 7s/step - loss: 0.0570 - accuracy: 0.9916 - val_loss: 1.0516 - val_accuracy: 0.7742
# Epoch 48/300
# 8/8 [==============================] - 54s 7s/step - loss: 0.0646 - accuracy: 0.9832 - val_loss: 2.1812 - val_accuracy: 0.7419
# Epoch 49/300
# 8/8 [==============================] - 54s 7s/step - loss: 0.1055 - accuracy: 0.9496 - val_loss: 0.9490 - val_accuracy: 0.7742
# Epoch 50/300
# 8/8 [==============================] - 54s 7s/step - loss: 0.1081 - accuracy: 0.9580 - val_loss: 0.8241 - val_accuracy: 0.7742
# Epoch 51/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.0536 - accuracy: 0.9748 - val_loss: 1.1016 - val_accuracy: 0.7419
# Epoch 52/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.0795 - accuracy: 0.9664 - val_loss: 0.9771 - val_accuracy: 0.7742
# Epoch 53/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.0398 - accuracy: 0.9916 - val_loss: 0.6967 - val_accuracy: 0.8387
# Epoch 54/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.0244 - accuracy: 1.0000 - val_loss: 0.6789 - val_accuracy: 0.8065
# Epoch 55/300
# 8/8 [==============================] - 54s 7s/step - loss: 0.0385 - accuracy: 0.9916 - val_loss: 0.7728 - val_accuracy: 0.8387
# Epoch 56/300
# 8/8 [==============================] - 54s 7s/step - loss: 0.0513 - accuracy: 0.9748 - val_loss: 1.0995 - val_accuracy: 0.7097
# Epoch 57/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.0429 - accuracy: 0.9748 - val_loss: 0.8278 - val_accuracy: 0.8065
# Epoch 58/300
# 8/8 [==============================] - 56s 7s/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.7933 - val_accuracy: 0.8065
# Epoch 59/300
# 8/8 [==============================] - 56s 8s/step - loss: 0.0354 - accuracy: 0.9832 - val_loss: 0.8125 - val_accuracy: 0.8065
# Epoch 60/300
# 8/8 [==============================] - 54s 7s/step - loss: 0.0505 - accuracy: 0.9748 - val_loss: 0.8550 - val_accuracy: 0.8065
# Epoch 61/300
# 8/8 [==============================] - 56s 7s/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.8791 - val_accuracy: 0.8065
# Epoch 62/300
# 8/8 [==============================] - 59s 7s/step - loss: 0.0443 - accuracy: 0.9844 - val_loss: 0.8891 - val_accuracy: 0.8065
# Epoch 63/300
# 8/8 [==============================] - 56s 7s/step - loss: 0.0218 - accuracy: 0.9916 - val_loss: 0.8741 - val_accuracy: 0.8065
# Epoch 64/300
# 8/8 [==============================] - 56s 7s/step - loss: 0.0254 - accuracy: 0.9916 - val_loss: 0.8520 - val_accuracy: 0.8065
# Epoch 65/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.0504 - accuracy: 0.9832 - val_loss: 0.8635 - val_accuracy: 0.8065
# Epoch 66/300
# 8/8 [==============================] - 53s 7s/step - loss: 0.0391 - accuracy: 0.9832 - val_loss: 0.8596 - val_accuracy: 0.8065
# Epoch 67/300
# 8/8 [==============================] - 54s 7s/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.8549 - val_accuracy: 0.8065
# Epoch 68/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.0472 - accuracy: 0.9916 - val_loss: 0.8656 - val_accuracy: 0.8065

# %%
# test_model = tf.keras.models.load_model("model_vggface_vggTCL 20SE.h5")

# %%
# test_model.evaluate(test_ds)

# %% [markdown]
# ## Evaluate the model on test set

# %%
model.evaluate(test_ds)
# Out:
# 2/2 [==============================] - 1s 139ms/step - loss: 0.3429 - accuracy: 0.8333
# [0.3429124057292938, 0.8333333134651184]

# %%
res = model.predict(test_ds)

# %%
res
# Out:
# array([[3.1949756e-05],
#        [3.0142069e-03],
#        [9.9782252e-01],
#        [9.9343622e-01],
#        [4.9991369e-02],
#        [9.3993235e-01],
#        [2.8797388e-03],
#        [6.8335938e-01],
#        [9.8294592e-01],
#        [2.6064754e-01],
#        [8.0044669e-01],
#        [4.4287145e-03],
#        [1.3520420e-03],
#        [9.8487639e-01],
#        [2.7781427e-03],
#        [9.9322760e-01],
#        [3.6258036e-01],
#        [6.9558728e-01]], dtype=float32)

# %%
res[res >= 0.5] = 1

# %%
res[res < 0.5] = 0

# %%
res
# Out:
# array([[0.],
#        [0.],
#        [1.],
#        [1.],
#        [0.],
#        [1.],
#        [0.],
#        [1.],
#        [1.],
#        [0.],
#        [1.],
#        [0.],
#        [0.],
#        [1.],
#        [0.],
#        [1.],
#        [0.],
#        [1.]], dtype=float32)
