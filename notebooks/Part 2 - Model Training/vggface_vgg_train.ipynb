# %% [markdown]
# # VGGFace (VGG16) Training

# %% [markdown]
# ## Import the necessary libraries

# %%
import matplotlib.pyplot as plt
import os
import sys
import tensorflow as tf
import warnings
from keras_vggface_TF.vggfaceTF import VGGFace
from keras_vggface_TF import utils

# %matplotlib inline

warnings.filterwarnings('ignore')
# Out:
# 2021-11-24 16:28:15.416485: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-11-24 16:28:15.416535: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
print('Python Version ' + sys.version)
print('TensorFlow Version ' + tf.__version__)

if int(sys.version[0]) < 3 or int(sys.version[2]) < 7:
    assert("Python version 3.7 or newer is required")
if int(tf.__version__[0]) < 2 or int(tf.__version__[2]) < 3:
    assert("Tensorflow version 2.3 or newer is required")
# Out:
# Python Version 3.9.0 (default, Nov 15 2020, 14:28:56)
# [GCC 7.3.0]
# TensorFlow Version 2.6.2

# %% [markdown]
# ## Set some common parameters

# %%
IMAGE_SIZE = 224
BATCH_SIZE = 16
EPOCHS = 200

CUR_PATH = os.path.abspath('')
TRAIN_PATH = CUR_PATH + '/../../../dataset/data/classified'
VALID_PATH = CUR_PATH + '/../../../dataset/data/validation'
TEST_PATH = CUR_PATH + '/../../../dataset/data/test'
SAVE_PATH = CUR_PATH + '/../../models'

os.makedirs(SAVE_PATH, exist_ok=True)

classes = {0 : "Baby",
           1 : "Not Baby"}

# %% [markdown]
# ## Define a Data Augmentation Proceedure / Function

# %%
def data_augment(image):
    p_spatial = tf.random.uniform([], 0, 1.0, dtype = tf.float32)
    p_rotate = tf.random.uniform([], 0, 1.0, dtype = tf.float32)
    p_pixel_1 = tf.random.uniform([], 0, 1.0, dtype = tf.float32)
    p_pixel_2 = tf.random.uniform([], 0, 1.0, dtype = tf.float32)
    p_pixel_3 = tf.random.uniform([], 0, 1.0, dtype = tf.float32)
    
    # Flips
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    
    if p_spatial > .75:
        image = tf.image.transpose(image)
        
    # Rotates
    if p_rotate > .75:
        image = tf.image.rot90(image, k = 3) # rotate 270º
    elif p_rotate > .5:
        image = tf.image.rot90(image, k = 2) # rotate 180º
    elif p_rotate > .25:
        image = tf.image.rot90(image, k = 1) # rotate 90º
        
    # Pixel-level transforms
    if p_pixel_1 >= .4:
        image = tf.image.random_saturation(image, lower = .7, upper = 1.3)
    if p_pixel_2 >= .4:
        image = tf.image.random_contrast(image, lower = .8, upper = 1.2)
    if p_pixel_3 >= .4:
        image = tf.image.random_brightness(image, max_delta = .1)
        
    return image

# %% [markdown]
# ## Define Data Generators

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255,
                                                          samplewise_center = True,
                                                          samplewise_std_normalization = True,
                                                          preprocessing_function = data_augment)

val_test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255,
                                                          samplewise_center = True,
                                                          samplewise_std_normalization = True)

val_test_datagen.apply_transform

train_ds = datagen.flow_from_directory(
        TRAIN_PATH,
        target_size=(IMAGE_SIZE, IMAGE_SIZE),
        batch_size=BATCH_SIZE,
        seed = 1,
        color_mode = 'rgb',
        shuffle = True,
        class_mode='binary')

val_ds = val_test_datagen.flow_from_directory(
        VALID_PATH,
        target_size=(IMAGE_SIZE, IMAGE_SIZE),
        batch_size=BATCH_SIZE,
        color_mode = 'rgb',
        shuffle = True,
        class_mode='binary')

test_ds = val_test_datagen.flow_from_directory(
        TEST_PATH,
        target_size=(IMAGE_SIZE, IMAGE_SIZE),
        batch_size=BATCH_SIZE,
        color_mode = 'rgb',
        class_mode='binary')
# Out:
# Found 135 images belonging to 2 classes.
# Found 31 images belonging to 2 classes.
# Found 18 images belonging to 2 classes.

# %%
x = train_ds.next()
image = x[0][0]
print(image.shape)
plt.imshow(image)
# Out:
# 2021-11-24 16:28:17.489664: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-11-24 16:28:17.489715: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-11-24 16:28:17.489751: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (snf-22339): /proc/driver/nvidia/version does not exist
# 2021-11-24 16:28:17.490237: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)

# %%
cat_img = plt.imread(TRAIN_PATH + '/baby/1.jpeg')

# %%
plt.imshow(cat_img)

# %% [markdown]
# ## Load the default VGGFace (VGG16) model

# %%
vgg_model = VGGFace(model='vgg16', include_top=False, input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3), pooling='avg')

# %% [markdown]
# ## Create a custom model

# %%
x = tf.keras.layers.Flatten(name='flatten')(vgg_model.output)
x = tf.keras.layers.Dense(32, activation='relu',)(x)
x = tf.keras.layers.Dense(16, activation='relu',)(x)
out = tf.keras.layers.Dense(1, activation='sigmoid', name='classifier')(x)
model = tf.keras.Model(vgg_model.input, out)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv1_1 (Conv2D)             (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv1_2 (Conv2D)             (None, 224, 224, 64)      36928
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2_1 (Conv2D)             (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2_2 (Conv2D)             (None, 112, 112, 128)     147584
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 56, 56, 128)       0
# _________________________________________________________________
# conv3_1 (Conv2D)             (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv3_2 (Conv2D)             (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv3_3 (Conv2D)             (None, 56, 56, 256)       590080
# _________________________________________________________________
# pool3 (MaxPooling2D)         (None, 28, 28, 256)       0
# _________________________________________________________________
# conv4_1 (Conv2D)             (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv4_2 (Conv2D)             (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv4_3 (Conv2D)             (None, 28, 28, 512)       2359808
# _________________________________________________________________
# pool4 (MaxPooling2D)         (None, 14, 14, 512)       0
# _________________________________________________________________
# conv5_1 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv5_2 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv5_3 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# pool5 (MaxPooling2D)         (None, 7, 7, 512)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                16416
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# classifier (Dense)           (None, 1)                 17
# =================================================================
# Total params: 14,731,649
# Trainable params: 14,731,649
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Define Callbacks

# %%
learning_rate = 1e-4

optimizer = tf.optimizers.Adam(learning_rate = learning_rate)

model.compile(optimizer = optimizer, 
              loss = tf.keras.losses.binary_crossentropy, 
              metrics = ['accuracy'])

STEP_SIZE_TRAIN = train_ds.n // train_ds.batch_size
# STEP_SIZE_VALID = val_ds.n // val_ds.batch_size

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_loss',
                                                 # verbose = 1,
                                                 factor = 0.2,
                                                 patience = 10,
                                                 min_delta = 1e-4,
                                                 min_lr = 1e-6,
                                                 mode = 'min')

earlystopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss',
                                                 # verbose = 1,
                                                 min_delta = 1e-4,
                                                 patience = 30,
                                                 mode = 'min',
                                                 restore_best_weights = True)

checkpointer = tf.keras.callbacks.ModelCheckpoint(monitor = 'val_loss',
                                                  # verbose = 1,
                                                  save_best_only = True,
                                                  save_weights_only = True,
                                                  mode = 'min',
                                                  filepath = './model_vggface_vgg.hdf5',
                                                  )

callbacks = [checkpointer, earlystopping, reduce_lr] #reduce_lr earlystopping

# %% [markdown]
# ## Training the Model

# %%
model.fit(x = train_ds,
          steps_per_epoch = STEP_SIZE_TRAIN,
          validation_data = val_ds,
          epochs = EPOCHS,
          callbacks = callbacks)

model.save(SAVE_PATH + '/model_vggface_vgg.h5')

os.remove('./model_vggface_vgg.hdf5')
# Out:
# 2021-11-24 16:28:19.686235: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/300
# 8/8 [==============================] - 58s 7s/step - loss: 0.6263 - accuracy: 0.6471 - val_loss: 1.2793 - val_accuracy: 0.5806
# Epoch 2/300
# 8/8 [==============================] - 58s 7s/step - loss: 0.7744 - accuracy: 0.6406 - val_loss: 0.7579 - val_accuracy: 0.5161
# Epoch 3/300
# 8/8 [==============================] - 54s 7s/step - loss: 0.6854 - accuracy: 0.5966 - val_loss: 0.7069 - val_accuracy: 0.5161
# Epoch 4/300
# 8/8 [==============================] - 56s 7s/step - loss: 0.6218 - accuracy: 0.6218 - val_loss: 0.6896 - val_accuracy: 0.5161
# Epoch 5/300
# 8/8 [==============================] - 57s 7s/step - loss: 0.5512 - accuracy: 0.7563 - val_loss: 0.8959 - val_accuracy: 0.6129
# Epoch 6/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.4028 - accuracy: 0.8403 - val_loss: 0.6211 - val_accuracy: 0.6452
# Epoch 7/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.4846 - accuracy: 0.7647 - val_loss: 0.4935 - val_accuracy: 0.7419
# Epoch 8/300
# 8/8 [==============================] - 58s 7s/step - loss: 0.4060 - accuracy: 0.8125 - val_loss: 0.8838 - val_accuracy: 0.6452
# Epoch 9/300
# 8/8 [==============================] - 53s 7s/step - loss: 0.3734 - accuracy: 0.8487 - val_loss: 0.5679 - val_accuracy: 0.6774
# Epoch 10/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.4548 - accuracy: 0.7899 - val_loss: 0.5313 - val_accuracy: 0.6774
# Epoch 11/300
# 8/8 [==============================] - 54s 7s/step - loss: 0.3746 - accuracy: 0.8739 - val_loss: 0.5676 - val_accuracy: 0.7097
# Epoch 12/300
# 8/8 [==============================] - 57s 7s/step - loss: 0.3163 - accuracy: 0.8319 - val_loss: 0.4212 - val_accuracy: 0.8065
# Epoch 13/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.2751 - accuracy: 0.8908 - val_loss: 0.5136 - val_accuracy: 0.7097
# Epoch 14/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.2651 - accuracy: 0.9244 - val_loss: 0.8210 - val_accuracy: 0.6774
# Epoch 15/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.2669 - accuracy: 0.8824 - val_loss: 0.9085 - val_accuracy: 0.6774
# Epoch 16/300
# 8/8 [==============================] - 57s 7s/step - loss: 0.5144 - accuracy: 0.7479 - val_loss: 0.5710 - val_accuracy: 0.6774
# Epoch 17/300
# 8/8 [==============================] - 60s 8s/step - loss: 0.4432 - accuracy: 0.7891 - val_loss: 0.7497 - val_accuracy: 0.6774
# Epoch 18/300
# 8/8 [==============================] - 57s 7s/step - loss: 0.3037 - accuracy: 0.8655 - val_loss: 0.4629 - val_accuracy: 0.8065
# Epoch 19/300
# 8/8 [==============================] - 56s 7s/step - loss: 0.2854 - accuracy: 0.8824 - val_loss: 0.8061 - val_accuracy: 0.7097
# Epoch 20/300
# 8/8 [==============================] - 56s 7s/step - loss: 0.3355 - accuracy: 0.8655 - val_loss: 0.4804 - val_accuracy: 0.7742
# Epoch 21/300
# 8/8 [==============================] - 56s 7s/step - loss: 0.3569 - accuracy: 0.8571 - val_loss: 0.4694 - val_accuracy: 0.7742
# Epoch 22/300
# 8/8 [==============================] - 54s 7s/step - loss: 0.4361 - accuracy: 0.8571 - val_loss: 0.4869 - val_accuracy: 0.7742
# Epoch 23/300
# 8/8 [==============================] - 56s 7s/step - loss: 0.3342 - accuracy: 0.8824 - val_loss: 0.4660 - val_accuracy: 0.7742
# Epoch 24/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.2852 - accuracy: 0.8824 - val_loss: 0.6249 - val_accuracy: 0.7097
# Epoch 25/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.2681 - accuracy: 0.8992 - val_loss: 0.6907 - val_accuracy: 0.7097
# Epoch 26/300
# 8/8 [==============================] - 57s 7s/step - loss: 0.2194 - accuracy: 0.9062 - val_loss: 0.4716 - val_accuracy: 0.7742
# Epoch 27/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.2448 - accuracy: 0.8992 - val_loss: 0.4985 - val_accuracy: 0.7419
# Epoch 28/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.1567 - accuracy: 0.9496 - val_loss: 0.5981 - val_accuracy: 0.7419
# Epoch 29/300
# 8/8 [==============================] - 57s 7s/step - loss: 0.1483 - accuracy: 0.9496 - val_loss: 0.5834 - val_accuracy: 0.7742
# Epoch 30/300
# 8/8 [==============================] - 57s 7s/step - loss: 0.1470 - accuracy: 0.9496 - val_loss: 0.5017 - val_accuracy: 0.7742
# Epoch 31/300
# 8/8 [==============================] - 55s 7s/step - loss: 0.1445 - accuracy: 0.9496 - val_loss: 0.6517 - val_accuracy: 0.7742
# Epoch 32/300
# 8/8 [==============================] - 58s 7s/step - loss: 0.1538 - accuracy: 0.9219 - val_loss: 0.6330 - val_accuracy: 0.7742
# Epoch 33/300
# 8/8 [==============================] - 60s 8s/step - loss: 0.1083 - accuracy: 0.9766 - val_loss: 0.5746 - val_accuracy: 0.7742
# Epoch 34/300
# 8/8 [==============================] - 56s 7s/step - loss: 0.1434 - accuracy: 0.9496 - val_loss: 0.6354 - val_accuracy: 0.8065
# Epoch 35/300
# 8/8 [==============================] - 57s 7s/step - loss: 0.1145 - accuracy: 0.9412 - val_loss: 0.6914 - val_accuracy: 0.7742
# Epoch 36/300
# 8/8 [==============================] - 56s 7s/step - loss: 0.1230 - accuracy: 0.9496 - val_loss: 0.6966 - val_accuracy: 0.7742
# Epoch 37/300
# 8/8 [==============================] - 57s 7s/step - loss: 0.1080 - accuracy: 0.9580 - val_loss: 0.6346 - val_accuracy: 0.7742
# Epoch 38/300
# 8/8 [==============================] - 54s 7s/step - loss: 0.1170 - accuracy: 0.9580 - val_loss: 0.5814 - val_accuracy: 0.7742
# Epoch 39/300
# 8/8 [==============================] - 60s 8s/step - loss: 0.1550 - accuracy: 0.9453 - val_loss: 0.6329 - val_accuracy: 0.7419
# Epoch 40/300
# 8/8 [==============================] - 56s 7s/step - loss: 0.0909 - accuracy: 0.9916 - val_loss: 0.6783 - val_accuracy: 0.7742
# Epoch 41/300
# 8/8 [==============================] - 57s 7s/step - loss: 0.1096 - accuracy: 0.9328 - val_loss: 0.6598 - val_accuracy: 0.7742
# Epoch 42/300
# 8/8 [==============================] - 54s 7s/step - loss: 0.1084 - accuracy: 0.9748 - val_loss: 0.6293 - val_accuracy: 0.7742

# %%
# test_model = tf.keras.models.load_model("model_vggface_vggTCL 20SE.h5")

# %%
# test_model.evaluate(test_ds)

# %% [markdown]
# ## Evaluate the model on test set

# %%
model.evaluate(test_ds)
# Out:
# 2/2 [==============================] - 1s 128ms/step - loss: 0.3980 - accuracy: 0.7778
# [0.3979753255844116, 0.7777777910232544]

# %%
res = model.predict(test_ds)

# %%
res
# Out:
# array([[9.4536996e-01],
#        [9.8850250e-01],
#        [1.1094302e-02],
#        [8.2597184e-01],
#        [2.4327636e-04],
#        [9.7172558e-03],
#        [9.2674059e-01],
#        [2.2296906e-03],
#        [1.7176238e-01],
#        [3.4214151e-01],
#        [7.1588457e-03],
#        [9.8404372e-01],
#        [3.8076824e-01],
#        [7.8488135e-01],
#        [2.6107499e-01],
#        [9.2610431e-01],
#        [5.1710755e-01],
#        [1.9910306e-02]], dtype=float32)

# %%
res[res >= 0.5] = 1

# %%
res[res < 0.5] = 0

# %%
res
# Out:
# array([[1.],
#        [1.],
#        [0.],
#        [1.],
#        [0.],
#        [0.],
#        [1.],
#        [0.],
#        [0.],
#        [0.],
#        [0.],
#        [1.],
#        [0.],
#        [1.],
#        [0.],
#        [1.],
#        [1.],
#        [0.]], dtype=float32)
