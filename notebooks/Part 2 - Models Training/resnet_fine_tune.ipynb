# %% [markdown]
# # ResNet-50 Fine-Tuning

# %% [markdown]
# ## Import the necessary libraries

# %%
import matplotlib.pyplot as plt
import os
import sys
import tensorflow as tf
import warnings

# %matplotlib inline

warnings.filterwarnings('ignore')
# Out:
# 2021-11-24 15:04:43.902268: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-11-24 15:04:43.902394: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
print('Python Version ' + sys.version)
print('TensorFlow Version ' + tf.__version__)

if int(sys.version[0]) < 3 or int(sys.version[2]) < 7:
    assert("Python version 3.7 or newer is required")
if int(tf.__version__[0]) < 2 or int(tf.__version__[2]) < 3:
    assert("Tensorflow version 2.3 or newer is required")
# Out:
# Python Version 3.9.0 (default, Nov 15 2020, 14:28:56)
# [GCC 7.3.0]
# TensorFlow Version 2.6.2

# %% [markdown]
# ## Set the common parameters

# %%
IMAGE_SIZE = 160
BATCH_SIZE = 16
EPOCHS = 100

CUR_PATH = os.path.abspath('')
TRAIN_PATH = CUR_PATH + '/../../../dataset/data/classified'
VALID_PATH = CUR_PATH + '/../../../dataset/data/validation'
TEST_PATH = CUR_PATH + '/../../../dataset/data/test'

classes = {0 : "Baby",
           1 : "Not Baby"}

# %% [markdown]
# ## Define a Data Augmentation Proceedure / Function

# %%
def data_augment(image):
    p_spatial = tf.random.uniform([], 0, 1.0, dtype = tf.float32)
    p_rotate = tf.random.uniform([], 0, 1.0, dtype = tf.float32)
    p_pixel_1 = tf.random.uniform([], 0, 1.0, dtype = tf.float32)
    p_pixel_2 = tf.random.uniform([], 0, 1.0, dtype = tf.float32)
    p_pixel_3 = tf.random.uniform([], 0, 1.0, dtype = tf.float32)
    
    # Flips
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    
    if p_spatial > .75:
        image = tf.image.transpose(image)
        
    # Rotates
    if p_rotate > .75:
        image = tf.image.rot90(image, k = 3) # rotate 270º
    elif p_rotate > .5:
        image = tf.image.rot90(image, k = 2) # rotate 180º
    elif p_rotate > .25:
        image = tf.image.rot90(image, k = 1) # rotate 90º
        
    # Pixel-level transforms
    if p_pixel_1 >= .4:
        image = tf.image.random_saturation(image, lower = .7, upper = 1.3)
    if p_pixel_2 >= .4:
        image = tf.image.random_contrast(image, lower = .8, upper = 1.2)
    if p_pixel_3 >= .4:
        image = tf.image.random_brightness(image, max_delta = .1)
        
    return image

# %% [markdown]
# ## Define Data Generators

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255,
                                                          samplewise_center = True,
                                                          samplewise_std_normalization = True,
                                                          preprocessing_function = data_augment)

val_test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255,
                                                          samplewise_center = True,
                                                          samplewise_std_normalization = True)

val_test_datagen.apply_transform

train_ds = datagen.flow_from_directory(
        TRAIN_PATH,
        target_size=(IMAGE_SIZE, IMAGE_SIZE),
        batch_size=BATCH_SIZE,
        seed = 1,
        color_mode = 'rgb',
        shuffle = True,
        class_mode='binary')

val_ds = val_test_datagen.flow_from_directory(
        VALID_PATH,
        target_size=(IMAGE_SIZE, IMAGE_SIZE),
        batch_size=BATCH_SIZE,
        color_mode = 'rgb',
        shuffle = True,
        class_mode='binary')

test_ds = val_test_datagen.flow_from_directory(
        TEST_PATH,
        target_size=(IMAGE_SIZE, IMAGE_SIZE),
        batch_size=BATCH_SIZE,
        color_mode = 'rgb',
        class_mode='binary')
# Out:
# Found 135 images belonging to 2 classes.
# Found 31 images belonging to 2 classes.
# Found 18 images belonging to 2 classes.

# %%
x = train_ds.next()
image = x[0][0]
print(image.shape)
plt.imshow(image)
# Out:
# 2021-11-24 15:05:20.707172: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-11-24 15:05:20.707250: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-11-24 15:05:20.707317: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (snf-22339): /proc/driver/nvidia/version does not exist
# 2021-11-24 15:05:20.708474: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (160, 160, 3)

# %%
cat_img = plt.imread(TRAIN_PATH + '/baby/1.jpeg')

# %%
plt.imshow(cat_img)

# %% [markdown]
# ## Load the default ResNet-50 Model

# %%
res_model = tf.keras.applications.resnet50.ResNet50(
    include_top=False, weights='imagenet', input_shape=(IMAGE_SIZE,IMAGE_SIZE,3), classes=2
)

res_model.trainable = False

# %% [markdown]
# ## Create the model

# %%
model = tf.keras.Sequential([
        res_model,
        tf.keras.layers.Flatten(),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dense(16, activation = "relu"),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dense(1, 'sigmoid')
    ],
    name = 'resnet50_custom')

model.summary()
# Out:
# Model: "resnet50_custom"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 5, 5, 2048)        23587712
# _________________________________________________________________
# flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 51200)             204800
# _________________________________________________________________
# dense (Dense)                (None, 16)                819216
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16)                64
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 24,611,809
# Trainable params: 921,665
# Non-trainable params: 23,690,144
# _________________________________________________________________

# %% [markdown]
# ## Define Callbacks

# %%
learning_rate = 1e-4

optimizer = tf.optimizers.Adam(learning_rate = learning_rate)

model.compile(optimizer = optimizer, 
              loss = tf.keras.losses.binary_crossentropy, 
              metrics = ['accuracy'])

STEP_SIZE_TRAIN = train_ds.n // train_ds.batch_size
# STEP_SIZE_VALID = val_ds.n // val_ds.batch_size

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_loss',
                                                 # verbose = 1,
                                                 factor = 0.2,
                                                 patience = 10,
                                                 min_delta = 1e-4,
                                                 min_lr = 1e-6,
                                                 mode = 'min')

earlystopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss',
                                                 # verbose = 1,
                                                 min_delta = 1e-4,
                                                 patience = 30,
                                                 mode = 'min',
                                                 restore_best_weights = True)

checkpointer = tf.keras.callbacks.ModelCheckpoint(monitor = 'val_loss', 
                                                  # verbose = 1, 
                                                  save_best_only = True,
                                                  save_weights_only = True,
                                                  mode = 'min',
                                                  filepath = './model_res.hdf5',)

callbacks = [checkpointer, earlystopping] #reduce_lr earlystopping

# %% [markdown]
# ## Train the Model

# %%
model.fit(x = train_ds,
          steps_per_epoch = STEP_SIZE_TRAIN,
          validation_data = val_ds,
          epochs = EPOCHS,
          callbacks = callbacks)

model.save('model_res_ft.h5')
# Out:
# 2021-11-24 15:05:33.390921: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 8/8 [==============================] - 12s 521ms/step - loss: 0.7506 - accuracy: 0.5882 - val_loss: 0.7580 - val_accuracy: 0.4516
# Epoch 2/100
# 8/8 [==============================] - 3s 304ms/step - loss: 0.5813 - accuracy: 0.6891 - val_loss: 0.7794 - val_accuracy: 0.5161
# Epoch 3/100
# 8/8 [==============================] - 2s 301ms/step - loss: 0.4661 - accuracy: 0.7899 - val_loss: 0.8021 - val_accuracy: 0.5484
# Epoch 4/100
# 8/8 [==============================] - 3s 304ms/step - loss: 0.5278 - accuracy: 0.7563 - val_loss: 0.8026 - val_accuracy: 0.5484
# Epoch 5/100
# 8/8 [==============================] - 3s 298ms/step - loss: 0.3790 - accuracy: 0.8235 - val_loss: 0.7904 - val_accuracy: 0.5484
# Epoch 6/100
# 8/8 [==============================] - 2s 294ms/step - loss: 0.3769 - accuracy: 0.8571 - val_loss: 0.7771 - val_accuracy: 0.6129
# Epoch 7/100
# 8/8 [==============================] - 3s 318ms/step - loss: 0.3750 - accuracy: 0.8594 - val_loss: 0.7869 - val_accuracy: 0.6129
# Epoch 8/100
# 8/8 [==============================] - 2s 326ms/step - loss: 0.3489 - accuracy: 0.8487 - val_loss: 0.7963 - val_accuracy: 0.5806
# Epoch 9/100
# 8/8 [==============================] - 2s 323ms/step - loss: 0.3846 - accuracy: 0.8235 - val_loss: 0.7936 - val_accuracy: 0.5806
# Epoch 10/100
# 8/8 [==============================] - 3s 320ms/step - loss: 0.2938 - accuracy: 0.8739 - val_loss: 0.7788 - val_accuracy: 0.6129
# Epoch 11/100
# 8/8 [==============================] - 3s 323ms/step - loss: 0.3269 - accuracy: 0.8828 - val_loss: 0.7644 - val_accuracy: 0.6129
# Epoch 12/100
# 8/8 [==============================] - 3s 312ms/step - loss: 0.2753 - accuracy: 0.8828 - val_loss: 0.7519 - val_accuracy: 0.6129
# Epoch 13/100
# 8/8 [==============================] - 3s 311ms/step - loss: 0.2742 - accuracy: 0.8908 - val_loss: 0.7483 - val_accuracy: 0.6129
# Epoch 14/100
# 8/8 [==============================] - 3s 324ms/step - loss: 0.2628 - accuracy: 0.9244 - val_loss: 0.7345 - val_accuracy: 0.6129
# Epoch 15/100
# 8/8 [==============================] - 3s 296ms/step - loss: 0.2266 - accuracy: 0.9328 - val_loss: 0.7429 - val_accuracy: 0.6129
# Epoch 16/100
# 8/8 [==============================] - 2s 294ms/step - loss: 0.2226 - accuracy: 0.9580 - val_loss: 0.7528 - val_accuracy: 0.6129
# Epoch 17/100
# 8/8 [==============================] - 3s 318ms/step - loss: 0.2735 - accuracy: 0.8992 - val_loss: 0.7638 - val_accuracy: 0.6129
# Epoch 18/100
# 8/8 [==============================] - 3s 311ms/step - loss: 0.1636 - accuracy: 0.9664 - val_loss: 0.7676 - val_accuracy: 0.6129
# Epoch 19/100
# 8/8 [==============================] - 3s 301ms/step - loss: 0.2286 - accuracy: 0.9160 - val_loss: 0.7678 - val_accuracy: 0.6129
# Epoch 20/100
# 8/8 [==============================] - 3s 306ms/step - loss: 0.2069 - accuracy: 0.9244 - val_loss: 0.7631 - val_accuracy: 0.6129
# Epoch 21/100
# 8/8 [==============================] - 2s 294ms/step - loss: 0.1670 - accuracy: 0.9580 - val_loss: 0.7668 - val_accuracy: 0.6129
# Epoch 22/100
# 8/8 [==============================] - 3s 306ms/step - loss: 0.2230 - accuracy: 0.9412 - val_loss: 0.7774 - val_accuracy: 0.6129
# Epoch 23/100
# 8/8 [==============================] - 3s 315ms/step - loss: 0.1683 - accuracy: 0.9664 - val_loss: 0.7930 - val_accuracy: 0.6129
# Epoch 24/100
# 8/8 [==============================] - 3s 321ms/step - loss: 0.1729 - accuracy: 0.9580 - val_loss: 0.8163 - val_accuracy: 0.6129
# Epoch 25/100
# 8/8 [==============================] - 2s 290ms/step - loss: 0.2031 - accuracy: 0.9412 - val_loss: 0.8235 - val_accuracy: 0.5806
# Epoch 26/100
# 8/8 [==============================] - 3s 325ms/step - loss: 0.1872 - accuracy: 0.9412 - val_loss: 0.7910 - val_accuracy: 0.5806
# Epoch 27/100
# 8/8 [==============================] - 3s 307ms/step - loss: 0.2353 - accuracy: 0.8908 - val_loss: 0.7795 - val_accuracy: 0.5806
# Epoch 28/100
# 8/8 [==============================] - 3s 308ms/step - loss: 0.1758 - accuracy: 0.9580 - val_loss: 0.7862 - val_accuracy: 0.6129
# Epoch 29/100
# 8/8 [==============================] - 3s 309ms/step - loss: 0.1426 - accuracy: 0.9916 - val_loss: 0.7892 - val_accuracy: 0.5484
# Epoch 30/100
# 8/8 [==============================] - 3s 311ms/step - loss: 0.1728 - accuracy: 0.9412 - val_loss: 0.7920 - val_accuracy: 0.5806
# Epoch 31/100
# 8/8 [==============================] - 3s 317ms/step - loss: 0.2074 - accuracy: 0.9244 - val_loss: 0.7709 - val_accuracy: 0.6129
# Epoch 32/100
# 8/8 [==============================] - 3s 315ms/step - loss: 0.1570 - accuracy: 0.9580 - val_loss: 0.7962 - val_accuracy: 0.6129
# Epoch 33/100
# 8/8 [==============================] - 3s 316ms/step - loss: 0.1273 - accuracy: 0.9748 - val_loss: 0.8037 - val_accuracy: 0.6452
# Epoch 34/100
# 8/8 [==============================] - 3s 303ms/step - loss: 0.1215 - accuracy: 0.9916 - val_loss: 0.7613 - val_accuracy: 0.6774
# Epoch 35/100
# 8/8 [==============================] - 3s 323ms/step - loss: 0.1703 - accuracy: 0.9496 - val_loss: 0.7340 - val_accuracy: 0.6774
# Epoch 36/100
# 8/8 [==============================] - 3s 298ms/step - loss: 0.1309 - accuracy: 0.9832 - val_loss: 0.7290 - val_accuracy: 0.6452
# Epoch 37/100
# 8/8 [==============================] - 3s 310ms/step - loss: 0.1310 - accuracy: 0.9664 - val_loss: 0.7177 - val_accuracy: 0.6129
# Epoch 38/100
# 8/8 [==============================] - 3s 298ms/step - loss: 0.1305 - accuracy: 0.9664 - val_loss: 0.6892 - val_accuracy: 0.6452
# Epoch 39/100
# 8/8 [==============================] - 3s 302ms/step - loss: 0.0996 - accuracy: 0.9832 - val_loss: 0.6807 - val_accuracy: 0.6452
# Epoch 40/100
# 8/8 [==============================] - 3s 294ms/step - loss: 0.1842 - accuracy: 0.9328 - val_loss: 0.7015 - val_accuracy: 0.6452
# Epoch 41/100
# 8/8 [==============================] - 2s 317ms/step - loss: 0.0945 - accuracy: 0.9916 - val_loss: 0.7171 - val_accuracy: 0.6129
# Epoch 42/100
# 8/8 [==============================] - 3s 302ms/step - loss: 0.1059 - accuracy: 0.9844 - val_loss: 0.7158 - val_accuracy: 0.6129
# Epoch 43/100
# 8/8 [==============================] - 3s 312ms/step - loss: 0.0954 - accuracy: 0.9832 - val_loss: 0.7280 - val_accuracy: 0.6129
# Epoch 44/100
# 8/8 [==============================] - 3s 336ms/step - loss: 0.1254 - accuracy: 0.9832 - val_loss: 0.7426 - val_accuracy: 0.6129
# Epoch 45/100
# 8/8 [==============================] - 2s 297ms/step - loss: 0.0976 - accuracy: 0.9916 - val_loss: 0.7192 - val_accuracy: 0.6452
# Epoch 46/100
# 8/8 [==============================] - 3s 302ms/step - loss: 0.1110 - accuracy: 0.9916 - val_loss: 0.7121 - val_accuracy: 0.6452
# Epoch 47/100
# 8/8 [==============================] - 2s 293ms/step - loss: 0.1747 - accuracy: 0.9580 - val_loss: 0.7085 - val_accuracy: 0.6452
# Epoch 48/100
# 8/8 [==============================] - 2s 287ms/step - loss: 0.0912 - accuracy: 0.9916 - val_loss: 0.6986 - val_accuracy: 0.6774
# Epoch 49/100
# 8/8 [==============================] - 3s 314ms/step - loss: 0.1121 - accuracy: 0.9748 - val_loss: 0.6536 - val_accuracy: 0.6774
# Epoch 50/100
# 8/8 [==============================] - 3s 302ms/step - loss: 0.1434 - accuracy: 0.9580 - val_loss: 0.6025 - val_accuracy: 0.7419
# Epoch 51/100
# 8/8 [==============================] - 3s 303ms/step - loss: 0.1113 - accuracy: 0.9832 - val_loss: 0.6233 - val_accuracy: 0.6774
# Epoch 52/100
# 8/8 [==============================] - 3s 316ms/step - loss: 0.0880 - accuracy: 0.9922 - val_loss: 0.6551 - val_accuracy: 0.6774
# Epoch 53/100
# 8/8 [==============================] - 3s 290ms/step - loss: 0.1112 - accuracy: 0.9664 - val_loss: 0.6534 - val_accuracy: 0.6774
# Epoch 54/100
# 8/8 [==============================] - 2s 315ms/step - loss: 0.0959 - accuracy: 0.9832 - val_loss: 0.6097 - val_accuracy: 0.7097
# Epoch 55/100
# 8/8 [==============================] - 3s 303ms/step - loss: 0.1386 - accuracy: 0.9412 - val_loss: 0.6436 - val_accuracy: 0.5806
# Epoch 56/100
# 8/8 [==============================] - 3s 315ms/step - loss: 0.1252 - accuracy: 0.9580 - val_loss: 0.6524 - val_accuracy: 0.5806
# Epoch 57/100
# 8/8 [==============================] - 3s 319ms/step - loss: 0.0608 - accuracy: 1.0000 - val_loss: 0.6504 - val_accuracy: 0.6129
# Epoch 58/100
# 8/8 [==============================] - 2s 296ms/step - loss: 0.1030 - accuracy: 0.9832 - val_loss: 0.6373 - val_accuracy: 0.6774
# Epoch 59/100
# 8/8 [==============================] - 3s 304ms/step - loss: 0.0559 - accuracy: 1.0000 - val_loss: 0.6252 - val_accuracy: 0.6452
# Epoch 60/100
# 8/8 [==============================] - 3s 315ms/step - loss: 0.1894 - accuracy: 0.9160 - val_loss: 0.6631 - val_accuracy: 0.6129
# Epoch 61/100
# 8/8 [==============================] - 3s 308ms/step - loss: 0.1125 - accuracy: 0.9664 - val_loss: 0.7154 - val_accuracy: 0.6774
# Epoch 62/100
# 8/8 [==============================] - 3s 313ms/step - loss: 0.1133 - accuracy: 0.9916 - val_loss: 0.7431 - val_accuracy: 0.7097
# Epoch 63/100
# 8/8 [==============================] - 2s 300ms/step - loss: 0.0759 - accuracy: 0.9832 - val_loss: 0.7427 - val_accuracy: 0.6774
# Epoch 64/100
# 8/8 [==============================] - 2s 300ms/step - loss: 0.0977 - accuracy: 0.9748 - val_loss: 0.7192 - val_accuracy: 0.6129
# Epoch 65/100
# 8/8 [==============================] - 3s 305ms/step - loss: 0.0923 - accuracy: 0.9832 - val_loss: 0.6844 - val_accuracy: 0.6774
# Epoch 66/100
# 8/8 [==============================] - 2s 300ms/step - loss: 0.0822 - accuracy: 0.9748 - val_loss: 0.5961 - val_accuracy: 0.6774
# Epoch 67/100
# 8/8 [==============================] - 3s 301ms/step - loss: 0.1000 - accuracy: 0.9832 - val_loss: 0.5815 - val_accuracy: 0.7097
# Epoch 68/100
# 8/8 [==============================] - 2s 291ms/step - loss: 0.0823 - accuracy: 1.0000 - val_loss: 0.5910 - val_accuracy: 0.6774
# Epoch 69/100
# 8/8 [==============================] - 2s 288ms/step - loss: 0.1093 - accuracy: 0.9664 - val_loss: 0.6080 - val_accuracy: 0.7097
# Epoch 70/100
# 8/8 [==============================] - 3s 306ms/step - loss: 0.0801 - accuracy: 0.9844 - val_loss: 0.6576 - val_accuracy: 0.6774
# Epoch 71/100
# 8/8 [==============================] - 3s 306ms/step - loss: 0.0646 - accuracy: 0.9832 - val_loss: 0.6524 - val_accuracy: 0.7097
# Epoch 72/100
# 8/8 [==============================] - 2s 294ms/step - loss: 0.0838 - accuracy: 0.9832 - val_loss: 0.6782 - val_accuracy: 0.7097
# Epoch 73/100
# 8/8 [==============================] - 2s 297ms/step - loss: 0.0727 - accuracy: 0.9916 - val_loss: 0.6842 - val_accuracy: 0.7419
# Epoch 74/100
# 8/8 [==============================] - 3s 299ms/step - loss: 0.1153 - accuracy: 0.9580 - val_loss: 0.7386 - val_accuracy: 0.7097
# Epoch 75/100
# 8/8 [==============================] - 3s 303ms/step - loss: 0.0677 - accuracy: 0.9916 - val_loss: 0.7272 - val_accuracy: 0.7097
# Epoch 76/100
# 8/8 [==============================] - 2s 295ms/step - loss: 0.1073 - accuracy: 0.9748 - val_loss: 0.6920 - val_accuracy: 0.7419
# Epoch 77/100
# 8/8 [==============================] - 2s 291ms/step - loss: 0.0878 - accuracy: 0.9832 - val_loss: 0.6639 - val_accuracy: 0.8065
# Epoch 78/100
# 8/8 [==============================] - 2s 283ms/step - loss: 0.0492 - accuracy: 1.0000 - val_loss: 0.6381 - val_accuracy: 0.8065
# Epoch 79/100
# 8/8 [==============================] - 2s 297ms/step - loss: 0.0654 - accuracy: 0.9916 - val_loss: 0.6283 - val_accuracy: 0.8065
# Epoch 80/100
# 8/8 [==============================] - 3s 324ms/step - loss: 0.0567 - accuracy: 0.9916 - val_loss: 0.6477 - val_accuracy: 0.7419
# Epoch 81/100
# 8/8 [==============================] - 3s 309ms/step - loss: 0.0636 - accuracy: 0.9916 - val_loss: 0.6799 - val_accuracy: 0.7419
# Epoch 82/100
# 8/8 [==============================] - 2s 299ms/step - loss: 0.0758 - accuracy: 1.0000 - val_loss: 0.6852 - val_accuracy: 0.7097
# Epoch 83/100
# 8/8 [==============================] - 2s 295ms/step - loss: 0.0744 - accuracy: 1.0000 - val_loss: 0.6924 - val_accuracy: 0.7419
# Epoch 84/100
# 8/8 [==============================] - 3s 327ms/step - loss: 0.0862 - accuracy: 0.9922 - val_loss: 0.6768 - val_accuracy: 0.7419
# Epoch 85/100
# 8/8 [==============================] - 2s 294ms/step - loss: 0.0533 - accuracy: 1.0000 - val_loss: 0.6601 - val_accuracy: 0.7419
# Epoch 86/100
# 8/8 [==============================] - 2s 286ms/step - loss: 0.0666 - accuracy: 1.0000 - val_loss: 0.6749 - val_accuracy: 0.7419
# Epoch 87/100
# 8/8 [==============================] - 3s 313ms/step - loss: 0.0774 - accuracy: 0.9916 - val_loss: 0.6834 - val_accuracy: 0.7419
# Epoch 88/100
# 8/8 [==============================] - 3s 299ms/step - loss: 0.0539 - accuracy: 1.0000 - val_loss: 0.6956 - val_accuracy: 0.7419
# Epoch 89/100
# 8/8 [==============================] - 3s 344ms/step - loss: 0.0445 - accuracy: 1.0000 - val_loss: 0.7108 - val_accuracy: 0.7419
# Epoch 90/100
# 8/8 [==============================] - 2s 296ms/step - loss: 0.0696 - accuracy: 0.9916 - val_loss: 0.7025 - val_accuracy: 0.7742
# Epoch 91/100
# 8/8 [==============================] - 2s 302ms/step - loss: 0.0553 - accuracy: 0.9916 - val_loss: 0.7103 - val_accuracy: 0.7742
# Epoch 92/100
# 8/8 [==============================] - 2s 286ms/step - loss: 0.0619 - accuracy: 0.9916 - val_loss: 0.7201 - val_accuracy: 0.7742
# Epoch 93/100
# 8/8 [==============================] - 3s 309ms/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 0.7572 - val_accuracy: 0.7419
# Epoch 94/100
# 8/8 [==============================] - 3s 305ms/step - loss: 0.0442 - accuracy: 0.9916 - val_loss: 0.7348 - val_accuracy: 0.7419
# Epoch 95/100
# 8/8 [==============================] - 3s 304ms/step - loss: 0.0737 - accuracy: 0.9664 - val_loss: 0.7290 - val_accuracy: 0.7742
# Epoch 96/100
# 8/8 [==============================] - 3s 316ms/step - loss: 0.0432 - accuracy: 1.0000 - val_loss: 0.7340 - val_accuracy: 0.7742
# Epoch 97/100
# 8/8 [==============================] - 2s 316ms/step - loss: 0.0865 - accuracy: 0.9748 - val_loss: 0.7277 - val_accuracy: 0.7742

# %% [markdown]
# ## Evaluate the model on test set

# %%
# test_model = tf.keras.models.load_model("model_res_ft.h5")

# %%
# test_model.evaluate(test_ds)

# %%
model.evaluate(test_ds)
# Out:
# 2/2 [==============================] - 1s 56ms/step - loss: 0.2187 - accuracy: 0.8889
# [0.21868565678596497, 0.8888888955116272]

# %%
res = model.predict(test_ds)

# %%
res
# Out:
# array([[9.49763894e-01],
#        [3.84070307e-01],
#        [9.64102149e-01],
#        [9.84049022e-01],
#        [1.46693885e-02],
#        [9.95232105e-01],
#        [3.92393023e-01],
#        [6.56932592e-04],
#        [9.89810228e-01],
#        [4.74343657e-01],
#        [6.08608127e-03],
#        [4.25982535e-01],
#        [9.52574372e-01],
#        [4.58037853e-02],
#        [2.99813598e-01],
#        [9.59060967e-01],
#        [9.49386835e-01],
#        [1.47307247e-01]], dtype=float32)

# %%
res[res >= 0.5] = 1

# %%
res[res < 0.5] = 0

# %%
res
# Out:
# array([[1.],
#        [0.],
#        [1.],
#        [1.],
#        [0.],
#        [1.],
#        [0.],
#        [0.],
#        [1.],
#        [0.],
#        [0.],
#        [0.],
#        [1.],
#        [0.],
#        [0.],
#        [1.],
#        [1.],
#        [0.]], dtype=float32)
